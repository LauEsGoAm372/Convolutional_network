# %% [markdown]
# <div>
# <img src="https://res-5.cloudinary.com/crunchbase-production/image/upload/c_lpad,h_256,w_256,f_auto,q_auto:eco/v1455514364/pim02bzqvgz0hibsra41.png" align="right"><br><br><FONT FACE="times new roman" SIZE=5>
# <b></b>
# <br>
# <i><b>Docente:</b></i> Camilo Rodriguez.
# <br>
# <i><b>Asignatura:</b></i> machine Learning
# <br>
# <i><b>Estudiante:</b></i> Laura GomeZ
# <br>
# <br> Mayo/2023
# <br>
# </FONT>
# </div>

# %% [markdown]
# #**Librerias**

# %%
#parte 1
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input, decode_predictions
import matplotlib.pyplot as plt
import numpy as np
import keras
from keras.models import Model
import pandas as pd
#parte 2
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, accuracy_score
from sklearn.metrics import r2_score

# %% [markdown]
# #**Parte 1**
#  Usar la red pre-entrenada VGG16 para clasificar imágenes(utilizar el notebook guía). (30 puntos)

# %% [markdown]
# ####**a)**Cargar 3, imágenes y utilizar la red para clasificarlas(determinar probabilidades)

# %%
model = VGG16()
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
# ...

# %%
# !wget https://www.shutterstock.com/image-photo/closeup-lamb-standing-on-grass-260nw-1655048893.jpg
# Out:
# --2023-05-25 04:24:36--  https://www.shutterstock.com/image-photo/closeup-lamb-standing-on-grass-260nw-1655048893.jpg
# Resolving www.shutterstock.com (www.shutterstock.com)... 13.227.219.26, 13.227.219.74, 13.227.219.110, ...
# Connecting to www.shutterstock.com (www.shutterstock.com)|13.227.219.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 31599 (31K) [image/jpeg]
# Saving to: ‘closeup-lamb-standing-on-grass-260nw-1655048893.jpg.5’
#
# closeup-lamb-standi 100%[===================>]  30.86K  --.-KB/s    in 0s
#
# 2023-05-25 04:24:36 (240 MB/s) - ‘closeup-lamb-standing-on-grass-260nw-1655048893.jpg.5’ saved [31599/31599]

# %%
img1 = keras.utils.image_utils.load_img("/content/closeup-lamb-standing-on-grass-260nw-1655048893.jpg",
                                       target_size=(224, 224),
                                       keep_aspect_ratio=True)
img1.show()
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F1591236C20>

# %%
#Se convierte la imagen a un arreglo
img1 = keras.utils.img_to_array(img1)

# %%
#Redimensionamos
img1 = img1.reshape(1, 224, 224, 3)

# %%
#Se procesa la imagen
img1 = preprocess_input(img1)

# %%
decode_predictions(model.predict(img1), top=5)
# Out:
# 1/1 [==============================] - 0s 151ms/step
# [[('n02412080', 'ram', 0.5073207),
#   ('n02437616', 'llama', 0.12837087),
#   ('n02113799', 'standard_poodle', 0.11847776),
#   ('n02104029', 'kuvasz', 0.07810063),
#   ('n02113712', 'miniature_poodle', 0.02473006)]]

# %% [markdown]
# ---

# %%
# !wget https://upload.wikimedia.org/wikipedia/commons/thumb/d/d0/RMS_Queen_Elizabeth_2_in_Trondheim_2008.jpg/1200px-RMS_Queen_Elizabeth_2_in_Trondheim_2008.jpg
# Out:
# --2023-05-25 04:24:37--  https://upload.wikimedia.org/wikipedia/commons/thumb/d/d0/RMS_Queen_Elizabeth_2_in_Trondheim_2008.jpg/1200px-RMS_Queen_Elizabeth_2_in_Trondheim_2008.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 91.198.174.208, 2620:0:862:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|91.198.174.208|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 222603 (217K) [image/jpeg]
# Saving to: ‘1200px-RMS_Queen_Elizabeth_2_in_Trondheim_2008.jpg.5’
#
# 1200px-RMS_Queen_El 100%[===================>] 217.39K  --.-KB/s    in 0.02s
#
# 2023-05-25 04:24:37 (14.1 MB/s) - ‘1200px-RMS_Queen_Elizabeth_2_in_Trondheim_2008.jpg.5’ saved [222603/222603]

# %%
img2 = keras.utils.image_utils.load_img("/content/1200px-RMS_Queen_Elizabeth_2_in_Trondheim_2008.jpg",target_size=(224, 224), keep_aspect_ratio=True)
img2.show()
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F15B896AF20>

# %%
#Se convierte la imagen a un arreglo
img2 = keras.utils.img_to_array(img2)

# %%
#Redimensionamos
img2 = img2.reshape(1, 224, 224, 3)

# %%
#Se procesa la imagen
img2 = preprocess_input(img2)

# %%
decode_predictions(model.predict(img2), top=5)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# [[('n03673027', 'liner', 0.67675537),
#   ('n02687172', 'aircraft_carrier', 0.1430948),
#   ('n03216828', 'dock', 0.14019682),
#   ('n03344393', 'fireboat', 0.014477126),
#   ('n03095699', 'container_ship', 0.0136282155)]]

# %% [markdown]
# ---

# %%
# !wget https://upload.wikimedia.org/wikipedia/commons/thumb/5/54/Light_sussex_hen.jpg/320px-Light_sussex_hen.jpg
# Out:
# --2023-05-25 04:24:37--  https://upload.wikimedia.org/wikipedia/commons/thumb/5/54/Light_sussex_hen.jpg/320px-Light_sussex_hen.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 91.198.174.208, 2620:0:862:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|91.198.174.208|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28274 (28K) [image/jpeg]
# Saving to: ‘320px-Light_sussex_hen.jpg.5’
#
# 320px-Light_sussex_ 100%[===================>]  27.61K  --.-KB/s    in 0.004s
#
# 2023-05-25 04:24:37 (6.01 MB/s) - ‘320px-Light_sussex_hen.jpg.5’ saved [28274/28274]

# %%
img3 = keras.utils.image_utils.load_img("/content/320px-Light_sussex_hen.jpg",
                                        target_size=(224, 224),
                                        keep_aspect_ratio=True)
img3.show()
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F159127C8B0>

# %%
img3 = keras.utils.img_to_array(img3)

# %%
img3 = img3.reshape(1, 224, 224, 3)

# %%
img3 = preprocess_input(img3)

# %%
decode_predictions(model.predict(img3), top=5)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# [[('n01514859', 'hen', 0.9412026),
#   ('n01514668', 'cock', 0.057055276),
#   ('n01807496', 'partridge', 0.0010168264),
#   ('n01797886', 'ruffed_grouse', 0.00023179727),
#   ('n01847000', 'drake', 0.00016338957)]]

# %% [markdown]
# ---

# %% [markdown]
# ####**b)** Visualizar la salida de la imagen de la guitarra para cada uno de los 64 filtros encontrados por la red en la primera capa(se muestra en el notebook un ejemplo)

# %%
# !wget https://upload.wikimedia.org/wikipedia/commons/2/24/Guitar_1.jpg
# Out:
# --2023-05-25 04:24:37--  https://upload.wikimedia.org/wikipedia/commons/2/24/Guitar_1.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 91.198.174.208, 2620:0:862:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|91.198.174.208|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 292923 (286K) [image/jpeg]
# Saving to: ‘Guitar_1.jpg.5’
#
# Guitar_1.jpg.5      100%[===================>] 286.06K  --.-KB/s    in 0.02s
#
# 2023-05-25 04:24:37 (16.4 MB/s) - ‘Guitar_1.jpg.5’ saved [292923/292923]

# %%
img_guitarra = keras.utils.image_utils.load_img("/content/Guitar_1.jpg",
                                       target_size=(224, 224),
                                       keep_aspect_ratio=True)

# %%
img_23 = keras.utils.img_to_array(img_guitarra)

# %%
img_33 = img_23.reshape(1, 224, 224, 3)

# %%
img_43 = preprocess_input(img_33)

# %%
decode_predictions(model.predict(img_43), top=5)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# [[('n02676566', 'acoustic_guitar', 0.99453706),
#   ('n03272010', 'electric_guitar', 0.0027954462),
#   ('n02787622', 'banjo', 0.0015215965),
#   ('n03929660', 'pick', 0.0005791291),
#   ('n04536866', 'violin', 0.00027907806)]]

# %%
# Obtener la salida de la capa convolucional para la imagen
outputs = model.layers[1].output

# Crear un modelo que toma la imagen de entrada y produce la salida de la capa convolucional
conv_model = Model(inputs=model.input, outputs=outputs)

# Obtener la salida de la capa convolucional para la imagen
conv_outputs = conv_model.predict(img_33)

# Visualizar la salida de los 64 filtros
fig, axs = plt.subplots(8, 8, figsize=(12, 12))

for i, ax in enumerate(axs.flatten()):
    ax.imshow(conv_outputs[0, :, :, i])
    ax.axis('off')

plt.show()
# Out:
# 1/1 [==============================] - 0s 39ms/step

# %% [markdown]
# ---

# %% [markdown]
# ####**c)** Visualizar la salida de la imagen de la guitarra después de aplicar la segunda capa de convolución.

# %%
# Obtener la salida de la capa convolucional para la imagen
outputs2 = model.layers[2].output

# Crear un modelo que toma la imagen de entrada y produce la salida de la capa convolucional
conv_model2 = Model(inputs=model.input, outputs=outputs2)

# Obtener la salida de la capa convolucional para la imagen
conv_outputs2 = conv_model.predict(img_43)

# Visualizar la salida de los 64 filtros
fig, axs = plt.subplots(8, 8, figsize=(12, 12))

for i, ax in enumerate(axs.flatten()):
    ax.imshow(conv_outputs2[0, :, :, i])
    ax.axis('off')

plt.show()
# Out:
# 1/1 [==============================] - 0s 34ms/step

# %% [markdown]
# ####**d)** Visualizar la salida de la imagen de la guitarra después de aplicar MaxPooling.

# %%
# Obtener la salida de la capa de MaxPooling para la imagen
pooling_outputs = model.layers[7].output

# Crear un modelo que toma la imagen de entrada y produce la salida de la capa de MaxPooling
pooling_model = Model(inputs=model.input, outputs=pooling_outputs)

pooling_outputs = pooling_model.predict(img_43)

# Obtener los tamaños de los ejes de pooling_outputs
_, pool_height, pool_width, num_filters = pooling_outputs.shape

# Visualizar la salida de los filtros después de aplicar MaxPooling
num_rows = num_filters // 8
num_cols = 8

fig, axs = plt.subplots(num_rows, num_cols, figsize=(12, 12))

for i, ax in enumerate(axs.flatten()):
    if i < num_filters:
        ax.imshow(pooling_outputs[0, :, :, i])
        ax.axis('off')
    else:
        ax.axis('off')

plt.show()
# Out:
# 1/1 [==============================] - 0s 110ms/step

# %% [markdown]
# ####**e)** Corroborar manualmente(con numpy) la salida de conv2d para el filtro 0 del punto b.

# %%
layer_1 = model.layers[1]
weights = layer_1.get_weights()[0]

filter_0 = weights[:, :, :, 0]

output_0 = np.zeros((222, 222))
for i in range(222):
    for j in range(222):
        output_0[i, j] = np.sum(img_43[0, i:i+3, j:j+3, :] * filter_0)
plt.imshow(output_0)
plt.axis('off')
plt.show()

# %% [markdown]
# #**Parte 2**
# Desarrollar una red neuronal usando Keras para el dataset de la diabetes.(https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_diabetes.html) (20 puntos)
# Utilizar 2 capas ocultas densas con función de activación Sigmoid.

# %% [markdown]
# ####**a)** Realizar la gráfica de número de iteraciones vs loss y gráfica de número de iteraciones vs mse. Determinar el óptimo # de iteraciones

# %%
df_diabetes = load_diabetes()
df_diabetes
# Out:
# {'data': array([[ 0.0380759064,  0.0506801187,  0.0616962065, ..., -0.002592262 ,
#           0.0199074862, -0.0176461252],
#         [-0.0018820165, -0.0446416365, -0.0514740612, ..., -0.0394933829,
#          -0.0683315471, -0.0922040496],
#         [ 0.0852989063,  0.0506801187,  0.0444512133, ..., -0.002592262 ,
#           0.0028613093, -0.025930339 ],
#         ...,
#         [ 0.0417084449,  0.0506801187, -0.0159062628, ..., -0.0110795198,
#          -0.0468825342,  0.0154907302],
#         [-0.0454724779, -0.0446416365,  0.039062153 , ...,  0.0265596235,
#           0.0445287288, -0.025930339 ],
#         [-0.0454724779, -0.0446416365, -0.0730303027, ..., -0.0394933829,
#          -0.0042215139,  0.0030644094]]),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
# ...

# %%
#Se define X y y
X = df_diabetes.data
y = df_diabetes.target

# %%
#Se escalan los datos aquiii
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
#Se divide en train y test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = Sequential()
model.add(Dense(128, input_dim=X.shape[1], activation='sigmoid'))
model.add(Dense(64, activation='sigmoid'))
model.add(Dense(1))

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=32, verbose=0)

# %%
# Variables para almacenar la pérdida y el MSE
loss = []
mse = []
np.set_printoptions(precision=10, suppress=True)
# Entrenar el modelo y calcular la pérdida y el MSE
for epoch in range(100):
    history = model.fit(X_train, y_train, epochs=1, batch_size=32, verbose=0)
    loss.append(history.history['loss'][0])

    # Calcular el MSE utilizando los valores predichos
    y_pred = model.predict(X_test)
    mse.append(mean_squared_error(y_test, y_pred))

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(1, len(loss)+1), loss)
plt.title('Número de Iteraciones vs Loss')
plt.xlabel('Iteraciones')
plt.ylabel('Loss')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(1, len(mse)+1), mse)
plt.title('Número de Iteraciones vs MSE')
plt.xlabel('Iteraciones')
plt.ylabel('MSE')
plt.grid(True)
plt.show()

# %%
# Calcular el MSE y R^2 en el conjunto de entrenamiento
y_train_pred = model.predict(X_train)
mse_train = mean_squared_error(y_train, y_train_pred)
r2_train = r2_score(y_train, y_train_pred)
print("MSE (entrenamiento):", mse_train)
print("Coeficiente R^2 (entrenamiento):", r2_train)

# Calcular el MSE y R^2 en el conjunto de prueba
y_test_pred = model.predict(X_test)
mse_test = mean_squared_error(y_test, y_test_pred)
r2_test = r2_score(y_test, y_test_pred)
print("MSE (prueba):", mse_test)
print("Coeficiente R^2 (prueba):", r2_test)
# Out:
# 10/10 [==============================] - 0s 2ms/step
# MSE (entrenamiento): 11251.769861136177
# Coeficiente R^2 (entrenamiento): -0.8300673523016042
# 5/5 [==============================] - 0s 3ms/step
# MSE (prueba): 9696.272317480174
# Coeficiente R^2 (prueba): -0.796168863498206

# %% [markdown]
# ####**b)** Calcular manualmente(desarrollar el propio código, hacerlo a mano o en Excel), la salida de la red para cualquiera  de los datos de entrada y corroborar los resultados obtenidos con Keras

# %%
input_data = X_test[0]

# %%
predicted_output = model.predict(np.array([input_data]))
print("Salida de la red neuronal:")
print(predicted_output)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# Salida de la red neuronal:
# [[82.46353]]

# %%
# Calcular manualmente la salida de la red para el mismo dato de entrada
weights = model.get_weights()
layer1_weights = weights[0]
layer1_biases = weights[1]
layer2_weights = weights[2]
layer2_biases = weights[3]
output_weights = weights[4]
output_biases = weights[5]

# %%
def sigmoid(z):
  return 1 / (1 + np.exp(-z))

# %%
def neurona(x,w):
  return np.dot(x,w)

# %%
#primera capa
layer1_output = sigmoid(neurona(input_data, layer1_weights) + layer1_biases )
#segunda capa
layer2_output = sigmoid(neurona(layer1_output, layer2_weights) +  layer2_biases )
#SALIDA
manual_output = neurona(layer2_output, output_weights) +  output_biases

# %%
print("Salida calculada manualmente:")
print(manual_output)
# Out:
# Salida calculada manualmente:
# [82.4635376153]

# %% [markdown]
# **En conclusión: lo calculado manualmente da igual a la implementación con keras**

# %%
print("Salida de la red neuronal Keras:")
print(predicted_output)
print("Salida calculada manualmente:")
print(manual_output)
# Out:
# Salida de la red neuronal Keras:
# [[82.46353]]
# Salida calculada manualmente:
# [82.4635376153]
